# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.io import wavfile
from scipy import signal
from scipy.io.wavfile import write
import IPython.display as ipd
import soundfile as sf

# %%
r_HRTF,fs = sf.read("originalsHRTF/0azright.wav")
r_HRTF90, fs = sf.read("originalsHRTF/80azright.wav")
r_HRTF270, fs = sf.read("originalsHRTF/neg80azright.wav")

l_HRTF,fs = sf.read("originalsHRTF/0azleft.wav")
l_HRTF90, fs = sf.read("originalsHRTF/80azleft.wav")
l_HRTF270, fs = sf.read("originalsHRTF/neg80azleft.wav")

r_HRTFbot = r_HRTF[0]
r_HRTFtop = r_HRTF[25]
r_HRTF0 = r_HRTF[8]
r_HRTF90 = r_HRTF90[8]
r_HRTF180 = r_HRTF[40]
r_HRTF270 = r_HRTF270[8]
R_HRTF = [r_HRTF0, r_HRTF180, r_HRTF90,  r_HRTF270, r_HRTFtop, r_HRTFbot]


l_HRTFbot = l_HRTF[0]
l_HRTFtop = l_HRTF[25]
l_HRTF0 = l_HRTF[8]
l_HRTF90 = l_HRTF90[8]
l_HRTF180 = l_HRTF[40]
l_HRTF270 = l_HRTF270[8]
L_HRTF = [l_HRTF0, l_HRTF180, l_HRTF90, l_HRTF270, l_HRTFtop, l_HRTFbot]

# %%
r_HRTF02 = np.zeros(256)
for i in range(200):
    r_HRTF02[i] = r_HRTF0[i] 
    
r_HRTF1802 = np.zeros(256)
for i in range(200):
    r_HRTF1802[i] = r_HRTF180[i]
    
r_HRTF902 = np.zeros(256)
for i in range(200):
    r_HRTF902[i] = r_HRTF90[i]
    
r_HRTF2702 = np.zeros(256)
for i in range(200):
    r_HRTF2702[i] = r_HRTF270[i]
    
r_HRTFtop2 = np.zeros(256)
for i in range(200):
    r_HRTFtop2[i] = r_HRTFtop[i]
    
r_HRTFbot2 = np.zeros(256)
for i in range(200):
    r_HRTFbot2[i] = r_HRTFbot[i]
    
r_HRTFbot2 = np.zeros(256)
for i in range(200):
    r_HRTFbot2[i] = r_HRTFbot[i]

    
    
l_HRTF02 = np.zeros(256)
for i in range(200):
    l_HRTF02[i] = l_HRTF0[i] 
    
l_HRTF1802 = np.zeros(256)
for i in range(200):
    l_HRTF1802[i] = l_HRTF180[i]
    
l_HRTF902 = np.zeros(256)
for i in range(200):
    l_HRTF902[i] = l_HRTF90[i]
    
l_HRTF2702 = np.zeros(256)
for i in range(200):
    l_HRTF2702[i] = l_HRTF270[i]
    
l_HRTFtop2 = np.zeros(256)
for i in range(200):
    l_HRTFtop2[i] = l_HRTFtop[i]
    
    
l_HRTFbot2 = np.zeros(256)
for i in range(200):
    l_HRTFbot2[i] = l_HRTFbot[i]

# %%
sf.write('r_HRTF0.wav', r_HRTF02, fs)
sf.write('r_HRTF90.wav', r_HRTF902, fs)
sf.write('r_HRTF180.wav', r_HRTF1802, fs)
sf.write('r_HRTF270.wav', r_HRTF2702, fs)
sf.write('r_HRTFtop.wav', r_HRTFtop2, fs)
sf.write('r_HRTFbot.wav', r_HRTFbot2, fs)

sf.write('l_HRTF0.wav', r_HRTF02, fs)
sf.write('l_HRTF90.wav', r_HRTF902, fs)
sf.write('l_HRTF180.wav', r_HRTF1802, fs)
sf.write('l_HRTF270.wav', r_HRTF2702, fs)
sf.write('l_HRTFtop.wav', r_HRTFtop2, fs)
sf.write('l_HRTFbot.wav', r_HRTFbot2, fs)
